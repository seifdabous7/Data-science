# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv('Pakistan_Ecommerce.xls')
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\326489435.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Pakistan_Ecommerce.xls')

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                111355 non-null  float64
#  1   status                 111352 non-null  object
#  2   created_at             111355 non-null  object
#  3   sku                    111351 non-null  object
#  4   price                  111355 non-null  float64
#  5   qty_ordered            111355 non-null  float64
#  6   grand_total            111355 non-null  float64
#  7   increment_id           111355 non-null  object
#  8   category_name_1        111328 non-null  object
#  9   sales_commission_code  85466 non-null   object
#  10  discount_amount        111355 non-null  float64
#  11  payment_method         111355 non-null  object
#  12  Working Date           111355 non-null  object
#  13  BI Status              111355 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# item_id                   88645
# status                    88648
# created_at                88645
# sku                       88649
# price                     88645
# qty_ordered               88645
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df.isnull().sum() *100/len(df)
# Out:
# item_id                   44.3225
# status                    44.3240
# created_at                44.3225
# sku                       44.3245
# price                     44.3225
# qty_ordered               44.3225
# grand_total               44.3225
# increment_id              44.3225
# category_name_1           44.3360
# sales_commission_code     57.2670
# discount_amount           44.3225
# payment_method            44.3225
# Working Date              44.3225
# BI Status                 44.3225
#  MV                       44.3225
# Year                      44.3225
# Month                     44.3225
# Customer Since            44.3225
# M-Y                       44.3225
# FY                        44.3225
# Customer ID               44.3225
# Unnamed: 21              100.0000
# Unnamed: 22              100.0000
# Unnamed: 23              100.0000
# Unnamed: 24              100.0000
# Unnamed: 25              100.0000
# dtype: float64

# %%
df['item_id']= df['item_id'].fillna('unknow')

# %%
df['item_id']= df['item_id'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 111352 non-null  object
#  2   created_at             111355 non-null  object
#  3   sku                    111351 non-null  object
#  4   price                  111355 non-null  float64
#  5   qty_ordered            111355 non-null  float64
#  6   grand_total            111355 non-null  float64
#  7   increment_id           111355 non-null  object
#  8   category_name_1        111328 non-null  object
#  9   sales_commission_code  85466 non-null   object
#  10  discount_amount        111355 non-null  float64
#  11  payment_method         111355 non-null  object
#  12  Working Date           111355 non-null  object
#  13  BI Status              111355 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                    88648
# created_at                88645
# sku                       88649
# price                     88645
# qty_ordered               88645
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['status'].value_counts()
# Out:
# status
# complete          44539
# canceled          38144
# received          14717
# order_refunded    11486
# refund             1554
# cod                 566
# paid                230
# closed               87
# payment_review        9
# processing            6
# pending               6
# holded                3
# \N                    2
# fraud                 2
# pending_paypal        1
# Name: count, dtype: int64

# %%
df['status'] = df['status'].replace('\\N', np.nan)

# %%
df['status'] = df['status'].fillna('Unknown')

# %%
df = df.dropna(subset=['status'])

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                88645
# sku                       88649
# price                     88645
# qty_ordered               88645
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             111355 non-null  object
#  3   sku                    111351 non-null  object
#  4   price                  111355 non-null  float64
#  5   qty_ordered            111355 non-null  float64
#  6   grand_total            111355 non-null  float64
#  7   increment_id           111355 non-null  object
#  8   category_name_1        111328 non-null  object
#  9   sales_commission_code  85466 non-null   object
#  10  discount_amount        111355 non-null  float64
#  11  payment_method         111355 non-null  object
#  12  Working Date           111355 non-null  object
#  13  BI Status              111355 non-null  object
# ...

# %%
df['created_at'].fillna(df['created_at'].mode(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\2511944183.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(df['created_at'].mode(),inplace=True)

# %%
df['created_at']= pd.to_datetime(df['created_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             111356 non-null  datetime64[ns]
#  3   sku                    111351 non-null  object
#  4   price                  111355 non-null  float64
#  5   qty_ordered            111355 non-null  float64
#  6   grand_total            111355 non-null  float64
#  7   increment_id           111355 non-null  object
#  8   category_name_1        111328 non-null  object
#  9   sales_commission_code  85466 non-null   object
#  10  discount_amount        111355 non-null  float64
#  11  payment_method         111355 non-null  object
#  12  Working Date           111355 non-null  object
#  13  BI Status              111355 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                88644
# sku                       88649
# price                     88645
# qty_ordered               88645
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['created_at'].fillna(method='ffill',inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\532112961.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(method='ffill',inplace=True)
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\532112961.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['created_at'].fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# sku                       88649
# price                     88645
# qty_ordered               88645
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df = df.drop(columns=['sku'])

# %%
df.describe()
# Out:
#                           created_at          price    qty_ordered  \
# count                         200000  111355.000000  111355.000000
# mean   2017-08-07 13:47:35.807999744    6270.352844       1.299331
# min              2016-07-01 00:00:00       0.000000       1.000000
# 25%              2017-01-26 00:00:00     360.000000       1.000000
# 50%              2017-08-15 00:00:00     899.000000       1.000000
# 75%              2018-01-30 00:00:00    4000.000000       1.000000
# max              2018-08-28 00:00:00  515975.000000    1000.000000
# std                              NaN   14713.018973       4.330947
#
#         grand_total  discount_amount           Year          Month  \
# count  1.113550e+05    111355.000000  111355.000000  111355.000000
# mean   8.394432e+03       492.117272    2017.041058       7.181186
# min   -1.311500e+03        -2.000000    2016.000000       1.000000
# 25%    9.400000e+02         0.000000    2017.000000       4.000000
# ...

# %%
df['price'].fillna(df['price'].median(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\50049080.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].median(),inplace=True)

# %%
df.describe()
# Out:
#                           created_at          price    qty_ordered  \
# count                         200000  200000.000000  111355.000000
# mean   2017-08-07 13:47:35.807999744    3889.634980       1.299331
# min              2016-07-01 00:00:00       0.000000       1.000000
# 25%              2017-01-26 00:00:00     750.000000       1.000000
# 50%              2017-08-15 00:00:00     899.000000       1.000000
# 75%              2018-01-30 00:00:00    1000.000000       1.000000
# max              2018-08-28 00:00:00  515975.000000    1000.000000
# std                              NaN   11298.058598       4.330947
#
#         grand_total  discount_amount           Year          Month  \
# count  1.113550e+05    111355.000000  111355.000000  111355.000000
# mean   8.394432e+03       492.117272    2017.041058       7.181186
# min   -1.311500e+03        -2.000000    2016.000000       1.000000
# 25%    9.400000e+02         0.000000    2017.000000       4.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df['price'] = scaler.fit_transform(df[['price']])

# %%
df.describe()
# Out:
#                           created_at         price    qty_ordered  \
# count                         200000  2.000000e+05  111355.000000
# mean   2017-08-07 13:47:35.807999744 -8.526513e-18       1.299331
# min              2016-07-01 00:00:00 -3.442755e-01       1.000000
# 25%              2017-01-26 00:00:00 -2.778922e-01       1.000000
# 50%              2017-08-15 00:00:00 -2.647041e-01       1.000000
# 75%              2018-01-30 00:00:00 -2.557645e-01       1.000000
# max              2018-08-28 00:00:00  4.532519e+01    1000.000000
# std                              NaN  1.000003e+00       4.330947
#
#         grand_total  discount_amount           Year          Month  \
# count  1.113550e+05    111355.000000  111355.000000  111355.000000
# mean   8.394432e+03       492.117272    2017.041058       7.181186
# min   -1.311500e+03        -2.000000    2016.000000       1.000000
# 25%    9.400000e+02         0.000000    2017.000000       4.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             200000 non-null  datetime64[ns]
#  3   price                  200000 non-null  float64
#  4   qty_ordered            111355 non-null  float64
#  5   grand_total            111355 non-null  float64
#  6   increment_id           111355 non-null  object
#  7   category_name_1        111328 non-null  object
#  8   sales_commission_code  85466 non-null   object
#  9   discount_amount        111355 non-null  float64
#  10  payment_method         111355 non-null  object
#  11  Working Date           111355 non-null  object
#  12  BI Status              111355 non-null  object
#  13   MV                    111355 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered               88645
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['qty_ordered'].fillna(df['qty_ordered'].mode(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\3344995893.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['qty_ordered'].fillna(df['qty_ordered'].mode(),inplace=True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered               88644
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             200000 non-null  datetime64[ns]
#  3   price                  200000 non-null  float64
#  4   qty_ordered            111356 non-null  float64
#  5   grand_total            111355 non-null  float64
#  6   increment_id           111355 non-null  object
#  7   category_name_1        111328 non-null  object
#  8   sales_commission_code  85466 non-null   object
#  9   discount_amount        111355 non-null  float64
#  10  payment_method         111355 non-null  object
#  11  Working Date           111355 non-null  object
#  12  BI Status              111355 non-null  object
#  13   MV                    111355 non-null  object
# ...

# %%
df['qty_ordered'].fillna(df['qty_ordered'].median(),inplace= True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\903418550.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['qty_ordered'].fillna(df['qty_ordered'].median(),inplace= True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total               88645
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['grand_total'].fillna(df['grand_total'].median(),inplace= True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\2608322025.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['grand_total'].fillna(df['grand_total'].median(),inplace= True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id              88645
# category_name_1           88672
# sales_commission_code    114534
# discount_amount           88645
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             200000 non-null  datetime64[ns]
#  3   price                  200000 non-null  float64
#  4   qty_ordered            200000 non-null  float64
#  5   grand_total            200000 non-null  float64
#  6   increment_id           111355 non-null  object
#  7   category_name_1        111328 non-null  object
#  8   sales_commission_code  85466 non-null   object
#  9   discount_amount        111355 non-null  float64
#  10  payment_method         111355 non-null  object
#  11  Working Date           111355 non-null  object
#  12  BI Status              111355 non-null  object
#  13   MV                    111355 non-null  object
# ...

# %%
df['increment_id'].fillna('unknow',inplace= True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\2645782259.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['increment_id'].fillna('unknow',inplace= True)

# %%
df['category_name_1'].fillna(df['category_name_1'].mode(),inplace= True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\2133325771.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['category_name_1'].fillna(df['category_name_1'].mode(),inplace= True)

# %%
df['sales_commission_code'].fillna(df['sales_commission_code'].mode(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\236929530.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sales_commission_code'].fillna(df['sales_commission_code'].mode(),inplace=True)

# %%
df['discount_amount'].fillna(df['discount_amount'].mean(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\3305089827.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['discount_amount'].fillna(df['discount_amount'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             200000 non-null  datetime64[ns]
#  3   price                  200000 non-null  float64
#  4   qty_ordered            200000 non-null  float64
#  5   grand_total            200000 non-null  float64
#  6   increment_id           200000 non-null  object
#  7   category_name_1        111329 non-null  object
#  8   sales_commission_code  85467 non-null   object
#  9   discount_amount        200000 non-null  float64
#  10  payment_method         111355 non-null  object
#  11  Working Date           111355 non-null  object
#  12  BI Status              111355 non-null  object
#  13   MV                    111355 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1           88671
# sales_commission_code    114533
# discount_amount               0
# payment_method            88645
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['payment_method'].fillna(df['payment_method'].mode(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\3643682312.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['payment_method'].fillna(df['payment_method'].mode(),inplace=True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1           88671
# sales_commission_code    114533
# discount_amount               0
# payment_method            88644
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['payment_method'].fillna(df['payment_method'].mode(),inplace=True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1           88671
# sales_commission_code    114533
# discount_amount               0
# payment_method            88644
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['payment_method'].value_counts().sort_values(ascending=False)
# Out:
# payment_method
# cod                  51922
# Payaxis              18680
# Easypay              15687
# jazzwallet            6638
# easypay_voucher       5839
# bankalfalah           4375
# jazzvoucher           2945
# Easypay_MA            2729
# customercredit        1457
# apg                    350
# ublcreditcard          176
# cashatdoorstep         151
# mygateway              149
# mcblite                133
# internetbanking         84
# productcredit           26
# marketingexpense        13
# financesettlement        2
# Name: count, dtype: int64

# %%
df['payment_method'].fillna('cod',inplace=True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1           88671
# sales_commission_code    114533
# discount_amount               0
# payment_method                0
# Working Date              88645
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             200000 non-null  datetime64[ns]
#  3   price                  200000 non-null  float64
#  4   qty_ordered            200000 non-null  float64
#  5   grand_total            200000 non-null  float64
#  6   increment_id           200000 non-null  object
#  7   category_name_1        111329 non-null  object
#  8   sales_commission_code  85467 non-null   object
#  9   discount_amount        200000 non-null  float64
#  10  payment_method         200000 non-null  object
#  11  Working Date           111355 non-null  object
#  12  BI Status              111355 non-null  object
#  13   MV                    111355 non-null  object
# ...

# %%
df['Working Date'].fillna(df['Working Date'].mode(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\2499568814.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Working Date'].fillna(df['Working Date'].mode(),inplace=True)

# %%
df['Working Date'] = pd.to_datetime(df['Working Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                200000 non-null  object
#  1   status                 200000 non-null  object
#  2   created_at             200000 non-null  datetime64[ns]
#  3   price                  200000 non-null  float64
#  4   qty_ordered            200000 non-null  float64
#  5   grand_total            200000 non-null  float64
#  6   increment_id           200000 non-null  object
#  7   category_name_1        111329 non-null  object
#  8   sales_commission_code  85467 non-null   object
#  9   discount_amount        200000 non-null  float64
#  10  payment_method         200000 non-null  object
#  11  Working Date           111356 non-null  datetime64[ns]
#  12  BI Status              111355 non-null  object
#  13   MV                    111355 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1           88671
# sales_commission_code    114533
# discount_amount               0
# payment_method                0
# Working Date              88644
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df['Working Date'].fillna(df['Working Date'].mode(),inplace=True)
# Out:
# C:\Users\seifa\AppData\Local\Temp\ipykernel_4272\2499568814.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Working Date'].fillna(df['Working Date'].mode(),inplace=True)

# %%
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1           88671
# sales_commission_code    114533
# discount_amount               0
# payment_method                0
# Working Date              88644
# BI Status                 88645
#  MV                       88645
# Year                      88645
# Month                     88645
# Customer Since            88645
# M-Y                       88645
# FY                        88645
# Customer ID               88645
# Unnamed: 21              200000
# Unnamed: 22              200000
# Unnamed: 23              200000
# Unnamed: 24              200000
# Unnamed: 25              200000
# dtype: int64

# %%
df.drop(['Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25'],axis=1,inplace=True)

# %%
num_cols = ['price', 'qty_ordered', 'grand_total', 'discount_amount']

# %%
for col in num_cols:
    plt.Figure(figsize=(8,6))
    sns.histplot(df[col],kde=True)
    plt.title(f'destripution of {col}')
    plt.show()

# %%
sns.pairplot(df[num_cols])
plt.show()
sns.heatmap(df[num_cols],annot=True,cmap='coolwarm')
plt.show()

# %%
cat_cols = ['status', 'payment_method', 'category_name_1', 'sales_commission_code']

# %%
for col in cat_cols:
    plt.figure(figsize =(8,6))
    sns.countplot(data = df,y = col, order=df[col].value_counts().index)
    plt.title(f'Count of {col}')
    plt.show()

# %%
pd.pivot_table(df, index='category_name_1', values='grand_total', aggfunc='mean')

# %%
grouped_data = df.groupby('Customer ID')['grand_total'].sum().describe()
