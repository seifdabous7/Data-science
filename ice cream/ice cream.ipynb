# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
data = pd.read_csv('ice_cream.csv')

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
plt.Figure(figsize=(8,6))
sns.histplot(df['Revenue'],kde=True)
plt.title('the distripution of revenu')
plt.show()

# %%
plt.Figure(figsize=(8,6))
sns.scatterplot(data=df,x='Temperature',y='Revenue')
plt.title('the relation between tempreture and revenu')
# Out:
# Text(0.5, 1.0, 'the relation between tempreture and revenu')

# %%
x = df['Temperature']
y = df['Revenue']

# %%
df.shape
# Out:
# (500, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=44, shuffle=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train.to_frame(), y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test.to_frame())

# %%
from sklearn.metrics import r2_score

# %%
accuracy = print(r2_score(y_test,y_pred))
# Out:
# 0.9802749969651278
